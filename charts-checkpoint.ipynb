# %%
import numpy as np

import pandas as pd
from pathlib import Path

import hvplot.pandas
import holoviews as hv

from holoviews import opts
from ipywidgets import widgets

import os
import requests
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
# from MCForecastTools import MCSimulation
# %matplotlib inline
import hvplot.pandas

# %%
# set the file path
SP500 = Path('../tre_spencer-main/S&P-financials.csv')
df_stock_data= pd.read_csv(SP500)
df_stock_data.head()
# Out:
#   Symbol                 Name                  Sector   Price  Price/Earnings  \
# 0    MMM           3M Company             Industrials  222.89           24.31
# 1    AOS      A.O. Smith Corp             Industrials   60.24           27.76
# 2    ABT  Abbott Laboratories             Health Care   56.27           22.51
# 3   ABBV          AbbVie Inc.             Health Care  108.48           19.41
# 4    ACN        Accenture plc  Information Technology  150.51           25.47
#
#    Dividend Yield  Earnings/Share  52 Week Low  52 Week High    Market Cap  \
# 0        2.332862            7.92       259.77       175.490  1.387210e+11
# 1        1.147959            1.70        68.39        48.925  1.078342e+10
# 2        1.908982            0.26        64.60        42.280  1.021210e+11
# 3        2.499560            3.29       125.86        60.050  1.813860e+11
# 4        1.714470            5.44       162.60       114.820  9.876586e+10
#
#          EBITDA  Price/Sales  Price/Book  \
# ...

# %%
df_stock_data.hvplot.scatter(x='Price',
                     y='Price/Earnings')
# Out:
# :Scatter   [Price]   (Price/Earnings)

# %%
# same chart but with dropdown -- can't seem to clear errors -- can be deleted
df_stock_data.hvplot.scatter(x='Price',
                     y='Price/Earnings')

def get_df(ticker, window_size):
    df_stock_data = pd.DataFrame(getattr(stocks, ticker))
    df_stock_data['Price'] = pd.to_datetime(df.date)
    return df.set_index('Price').rolling(window=window_size).mean().reset_index()
                             
def get_plot(ticker, window_size):
    df_stock_data = get_df(ticker, window_size)
    return df_stock_data.hvplot.line('Price', 'Price/Earnings', grid=True, responsive=True, height=300)

interact = pn.interact(get_plot, ticker=tickers, window_size=(1, 21, 5))

pn.Row(
    pn.Column(title, interact[0]),
    interact[1]
# Out:
#   File "C:\Users\treve\AppData\Local\Temp\ipykernel_67828\252220527.py", line 18
#     interact[1]
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
stocks = df_stock_data['Symbol'].unique().tolist()
print(stocks)
# Out:
# ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'AYI', 'ADBE', 'AAP', 'AMD', 'AES', 'AET', 'AMG', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE', 'ALXN', 'ALGN', 'ALLE', 'AGN', 'ADS', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'APC', 'ADI', 'ANDV', 'ANSS', 'ANTM', 'AON', 'APA', 'AIV', 'AAPL', 'AMAT', 'APTV', 'ADM', 'ARNC', 'AJG', 'AIZ', 'T', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BHGE', 'BLL', 'BAC', 'BAX', 'BBT', 'BDX', 'BRK.B', 'BBY', 'BIIB', 'BLK', 'HRB', 'BA', 'BWA', 'BXP', 'BSX', 'BHF', 'BMY', 'AVGO', 'BF.B', 'CHRW', 'CA', 'COG', 'CDNS', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CAT', 'CBOE', 'CBG', 'CBS', 'CELG', 'CNC', 'CNP', 'CTL', 'CERN', 'CF', 'SCHW', 'CHTR', 'CHK', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'XEC', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'GLW', 'COST', 'COTY', 'CCI', 'CSRA', 'CSX', 'CMI', 'CVS', 'DHI', 'DH
# ...

# %%
# tried to code chart that where we can select a individual stock
import panel as pn

# Create a list of stock names
stocks = ['Stock A', 'Stock B', 'Stock C'] 
# Create a dropdown widget with the stock names as options
stock_dropdown = pn.widgets.Select(name='Stock', options=stocks)

# Create a function that updates the plot based on the selected stock
def update(event):
    # Get the selected stock
    stock = event.new
    # Update the data in the plot to show data for the selected stock
    df_stock_data.hvplot(x='Dividend Yield',
                         y='Price/Earnings',
                         kind='line', size=20,
                         color='green',
                         data=df_stock_data[df_stock_data['Stock'] == stock])

# Link the dropdown widget to the update function
stock_dropdown.param.watch(update, 'value')

# Display the dropdown widget and the plot
pn.Column(stock_dropdown, df_stock_data.hvplot(x='Dividend Yield',
                                                y='Price/Earnings',
                                                kind='line', size=20,
                                                color='green')).servable()
# Out:
# Column
#     [0] Select(name='Stock', options=['Stock A', 'Stock B', ...], value='Stock A')
#     [1] HoloViews(Curve)

# %%
# this can be deleted
# Extract a list of the unique stock names
stocks = df_stock_data['Symbol'].unique().tolist()

# Create a multi-select widget with the stock names as options
stock_select = pn.widgets.MultiSelect(name='Stocks', options=stocks)

# Create a function that updates the plot based on the selected stocks
def update(event):
    # Get the selected stocks
    selected_stocks = event.new
    # Update the data in the plot to show data for the selected stocks
    df_plot = df[df['Symbol'].isin(selected_stocks)]
    df_plot.hvplot(x='Dividend Yield',
                   y='Price/Earnings',
                   kind='line', size=20,
                   color='red')

# Link the multi-select widget to the update function
stock_select.param.watch(update, 'value')

# Display the multi-select widget and the plot
pn.Column(stock_select, df_stock_data.hvplot(x='Dividend Yield',
                                  y='Price/Earnings',
                                  kind='line', size=20,
                                  color='red')).servable()
# Out:
# Column
#     [0] MultiSelect(name='Stocks', options=['MMM', 'AOS', ...])
#     [1] HoloViews(Curve)

# %%
df_stock_data.groupby('Symbol').mean().hvplot(y='Price/Earnings')
# Out:
# :Curve   [Symbol]   (Price/Earnings)
